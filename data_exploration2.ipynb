# %% [markdown]
# # Data Exploration-II

# %%
# %matplotlib inline
from PIL import Image
from scipy.io import wavfile
from IPython.display import Audio
import numpy as np
import matplotlib.pyplot as plt

# %%
# Images
img = Image.open("data/dog.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x720 at 0x7F436C896F60>

# %%
img_array = np.asarray(img)
img_array.shape
# Out:
# (720, 960, 3)

# %%
img_array.ravel().shape
# Out:
# (2073600,)

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
# Sound
rate, sound = wavfile.read(filename='data/cat_y.wav')
Audio(data=sound, rate=rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len(sound)
# Out:
# 49016

# %%
sound
# Out:
# array([128, 128, 128, ..., 127, 127, 127], dtype=uint8)

# %%
plt.plot(sound)

# %%
_ = plt.specgram(sound, NFFT=1024, Fs=44100)
plt.ylabel('Frequency (Hz)')
plt.xlabel('Time (s)')
